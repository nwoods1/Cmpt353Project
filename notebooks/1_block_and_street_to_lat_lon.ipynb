# %% [markdown]
# # Block + Street Name to Latitude and Longitude
#
# Using Geopy and Nominatim, we use our collection of Blocks and Streets and determine the latitude and longitude.
#
# Note: Nominatim is rate limited to 1 request, per second, so depending on the incoming data size, the processing may take a while.

# %%
import os
import time

from geopy.geocoders import Nominatim
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../data/cleaned_data/parking_tickets.csv")

# only keep the block and street columns
columns = set(df.columns)
columns.remove("Block")
columns.remove("Street")
df = df.drop(columns, axis=1)

# remove duplicates
df = df.drop_duplicates()
df.head()
# Out:
#    Block       Street
# 0    800  RICHARDS ST
# 1    300    E 8TH AVE
# 2    500   E 19TH AVE
# 3    500   E 17TH AVE
# 4    100   E 20TH AVE

# %%
# hacky work-around: Nominatim can't provide a lat/lon for these places
# drop_rows = [
#     (1200, "LAMEYS MILL RD"),
#     (1300, "LAMEYS MILL RD"),
#     (1400, "LAMEYS MILL RD"),
# ]

df = df.drop(df[(df["Street"].str.endswith("P"))].index) # examples: BIRCH WALK P, SPRINGTREE 
df = df.drop(df[(df["Street"] == "LAMEYS MILL RD")].index)
df = df.drop(df[(df["Street"] == "BONSAI ST")].index)
df = df.drop(df[(df["Street"] == "MENCHION MEWS")].index)
df = df.drop(df[(df["Street"] == "THELLAIWHALTUN AVE")].index)

# for block, street in drop_rows:
#     df = df.drop(df[(df["Block"] == block) & (df["Street"] == street)].index)

# %%
geolocator = Nominatim(user_agent="cmpt_353_project_1")

counter = [0]
total_rows = df.shape[0]

# %%
# track the progress of the computation
progress_file = "progress.txt"
if os.path.exists(progress_file):
    with open(progress_file, "r") as f:
        counter[0] = int(f.read().strip())  # Read the last processed index

# %%
chunk_size = 25
# Create chunks starting from counter[0]
chunks = [df.iloc[i:i + chunk_size] for i in range(counter[0], total_rows, chunk_size)]

# Sanity check
total_chunked_size = sum(chunk_df.shape[0] for chunk_df in chunks)
expected_size = total_rows - counter[0] 
assert total_chunked_size == expected_size, \
    f"Mismatch: {total_chunked_size} != {expected_size} (expected {expected_size})"

# %%
cached_df = pd.read_csv("../data/cleaned_data/cache_block_street_with_lat_lon.csv")
cached_df = cached_df.drop_duplicates()

# %%
def get_lat_lon(block, street, counter):
    address = f"{block} {street}, Vancouver, BC"
    print(f"Attempting to find lat/lon for {address}")
    # search cached_df
    filtered_df = cached_df.loc[(df["Block"] == block) & (cached_df["Street"] == "street")]
    if not filtered_df.empty:
        print(f"{counter[0]}/{total_rows} - {address}: {location.latitude}, {location.longitude}  | ~{((total_rows - counter[0]) / 60):.2f} minutes remaining")
        counter[0] += 1
        row = df.iloc[0]
        return row["lat"], row["lon"]
    
    retries = 5
    time.sleep(0.9)  # Rate limited to 1 request per second
    i = 0
    
    while i < retries:
        try:
            location = geolocator.geocode(address, timeout=2)
            
            if location:
                print(f"{counter[0]}/{total_rows} - {address}: {location.latitude}, {location.longitude}  | ~{((total_rows - counter[0]) / 60):.2f} minutes remaining")
                counter[0] += 1
                return location.latitude, location.longitude
        except Exception as e:
            i += 1
            print(f"Error: {e}...trying again for attempt {i} / {retries}")
    
    counter[0] += 1
    return np.nan, np.nan

# %%
out_file = "../data/cleaned_data/block_street_with_lat_lon.csv"

# %%
for chunk_df in chunks:
    chunk_df = chunk_df.copy()
    chunk_df.loc[:,"lat"], chunk_df.loc[:,"lon"] = zip(*chunk_df.apply(
        lambda row: get_lat_lon(row["Block"], row["Street"], counter), 
        axis=1
    ))
    
    if counter[0] != chunk_size:
        chunk_df.to_csv(out_file, mode="a", header=False, index=False)
    else: # write to a fresh file
        chunk_df.to_csv(out_file, mode="w", header=True, index=False) 
    
    print(f"Wrote chunk {int((counter[0] + 1) / chunk_size)} to {out_file}")
    
    # bookmark progress
    with open(progress_file, "w") as f:
        f.write(str(counter[0]))
# Out:
# Attempting to find lat/lon for 900 W BROADWAY, Vancouver, BC
# 4000/4131 - 900 W BROADWAY, Vancouver, BC: 49.263649475047416, -123.1389344042681  | ~2.18 minutes remaining
# Attempting to find lat/lon for 8500 SHAUGHNESSY ST, Vancouver, BC
# 4001/4131 - 8500 SHAUGHNESSY ST, Vancouver, BC: 49.21183978978081, -123.12876973011937  | ~2.17 minutes remaining
# Attempting to find lat/lon for 700 W 27TH AVE, Vancouver, BC
# 4002/4131 - 700 W 27TH AVE, Vancouver, BC: 49.24716431798934, -123.12360598755744  | ~2.15 minutes remaining
# Attempting to find lat/lon for 3600 SCALES PLACE, Vancouver, BC
# 4003/4131 - 3600 SCALES PLACE, Vancouver, BC: 49.24058028018964, -123.02507638257093  | ~2.13 minutes remaining
# Attempting to find lat/lon for 4000 W 28TH AVE, Vancouver, BC
# 4004/4131 - 4000 W 28TH AVE, Vancouver, BC: 49.247115907458166, -123.18197003463287  | ~2.12 minutes remaining
# Attempting to find lat/lon for 6900 FREMLIN ST, Vancouver, BC
# 4005/4131 - 6900 FREMLIN ST, Vancouver, BC: 49.20991518931212, -123.12744330100803  | ~2.10 minutes remaining
# Attempting to find lat/lon for 700 W 64TH AVE, Vancouver, BC
# 4006/4131 - 700 W 64TH AVE, Vancouver, BC: 49.21328707759695, -123.149469435529  | ~2.08 minutes remaining
# Attempting to find lat/lon for 700 CLARK DRIVE, Vancouver, BC
# 4007/4131 - 700 CLARK DRIVE, Vancouver, BC: 49.28202302348328, -123.0770833260843  | ~2.07 minutes remaining
# Attempting to find lat/lon for 2500 SE MARINE DRIVE, Vancouver, BC
# 4008/4131 - 2500 SE MARINE DRIVE, Vancouver, BC: 49.21101899615082, -123.0791664987635  | ~2.05 minutes remaining
# Attempting to find lat/lon for 4900 WINDSOR ST, Vancouver, BC
# 4009/4131 - 4900 WINDSOR ST, Vancouver, BC: 49.26290687922258, -123.08329920426632  | ~2.03 minutes remaining
# Attempting to find lat/lon for 700 E 53RD AVE, Vancouver, BC
# 4010/4131 - 700 E 53RD AVE, Vancouver, BC: 49.221797459285646, -123.0925389202363  | ~2.02 minutes remaining
# Attempting to find lat/lon for 2700 NANAIMO ST, Vancouver, BC
# 4011/4131 - 2700 NANAIMO ST, Vancouver, BC: 49.278484965548074, -123.05658138859958  | ~2.00 minutes remaining
# Attempting to find lat/lon for 1800 EAST KENT AVE N, Vancouver, BC
# 4012/4131 - 1800 EAST KENT AVE N, Vancouver, BC: 49.20934943755498, -123.07738934857956  | ~1.98 minutes remaining
# Attempting to find lat/lon for 2900 TISDALL ST, Vancouver, BC
# 4013/4131 - 2900 TISDALL ST, Vancouver, BC: 49.22267027369213, -123.1207582217214  | ~1.97 minutes remaining
# Attempting to find lat/lon for 800 W 14TH AVE, Vancouver, BC
# 4014/4131 - 800 W 14TH AVE, Vancouver, BC: 49.25867062193298, -123.12341669858058  | ~1.95 minutes remaining
# Attempting to find lat/lon for 2800 E 48TH AVE, Vancouver, BC
# 4015/4131 - 2800 E 48TH AVE, Vancouver, BC: 49.226267015725846, -123.06241843206102  | ~1.93 minutes remaining
# Attempting to find lat/lon for 3400 FOSTER AVE, Vancouver, BC
# 4016/4131 - 3400 FOSTER AVE, Vancouver, BC: 49.23402505313229, -123.02957485058202  | ~1.92 minutes remaining
# Attempting to find lat/lon for 1400 W 57TH AVE, Vancouver, BC
# 4017/4131 - 1400 W 57TH AVE, Vancouver, BC: 49.219138322749316, -123.12302621764834  | ~1.90 minutes remaining
# Attempting to find lat/lon for 3600 MOSCROP ST, Vancouver, BC
# 4018/4131 - 3600 MOSCROP ST, Vancouver, BC: 49.24353648613477, -123.02752843171575  | ~1.88 minutes remaining
# Attempting to find lat/lon for 4400 JAMES ST, Vancouver, BC
# 4019/4131 - 4400 JAMES ST, Vancouver, BC: 49.24511540698387, -123.1038757681812  | ~1.87 minutes remaining
# Attempting to find lat/lon for 0 E 33RD AVE, Vancouver, BC
# 4020/4131 - 0 E 33RD AVE, Vancouver, BC: 49.24033435, -123.09238685  | ~1.85 minutes remaining
# Attempting to find lat/lon for 2700 ALDER ST, Vancouver, BC
# 4021/4131 - 2700 ALDER ST, Vancouver, BC: 49.259951199730736, -123.13150509283193  | ~1.83 minutes remaining
# Attempting to find lat/lon for 2400 W 35TH AVE, Vancouver, BC
# 4022/4131 - 2400 W 35TH AVE, Vancouver, BC: 49.240400244675655, -123.16535093031861  | ~1.82 minutes remaining
# Attempting to find lat/lon for 1700 W 37TH AVE, Vancouver, BC
# 4023/4131 - 1700 W 37TH AVE, Vancouver, BC: 49.23731905788833, -123.11888712259989  | ~1.80 minutes remaining
# Attempting to find lat/lon for 0 W 27TH AVE, Vancouver, BC
# 4024/4131 - 0 W 27TH AVE, Vancouver, BC: 49.24716431798934, -123.12360598755744  | ~1.78 minutes remaining
# Wrote chunk 161 to ../data/cleaned_data/block_street_with_lat_lon.csv
# Attempting to find lat/lon for 3400 SLOCAN ST, Vancouver, BC
# 4025/4131 - 3400 SLOCAN ST, Vancouver, BC: 49.265755236429555, -123.0495334  | ~1.77 minutes remaining
# Attempting to find lat/lon for 800 HEATLEY AVE, Vancouver, BC
# 4026/4131 - 800 HEATLEY AVE, Vancouver, BC: 49.28208361166738, -123.08949670571211  | ~1.75 minutes remaining
# Attempting to find lat/lon for 2200 E 48TH AVE, Vancouver, BC
# 4027/4131 - 2200 E 48TH AVE, Vancouver, BC: 49.226267015725846, -123.06241843206102  | ~1.73 minutes remaining
# 4043/4131 - 2400 W 36TH AVE, Vancouver, BC: 49.23953773703653, -123.18776087125211  | ~1.47 minutes remaining
# Attempting to find lat/lon for 1700 W 61ST AVE, Vancouver, BC
# 4044/4131 - 1700 W 61ST AVE, Vancouver, BC: 49.21606009783829, -123.15193479616242  | ~1.45 minutes remaining
# Attempting to find lat/lon for 2700 VICTORIA DRIVE, Vancouver, BC
# 4045/4131 - 2700 VICTORIA DRIVE, Vancouver, BC: 49.2460053912135, -123.06508605765929  | ~1.43 minutes remaining
# Attempting to find lat/lon for 4200 NANAIMO ST, Vancouver, BC
# 4046/4131 - 4200 NANAIMO ST, Vancouver, BC: 49.278484965548074, -123.05658138859958  | ~1.42 minutes remaining
# Attempting to find lat/lon for 1300 HOWE ST, Vancouver, BC
# 4047/4131 - 1300 HOWE ST, Vancouver, BC: 49.28478563333309, -123.11664266117666  | ~1.40 minutes remaining
# Attempting to find lat/lon for 6400 FREMLIN ST, Vancouver, BC
# 4048/4131 - 6400 FREMLIN ST, Vancouver, BC: 49.20991518931212, -123.12744330100803  | ~1.38 minutes remaining
# Attempting to find lat/lon for 4600 W 4TH AVE, Vancouver, BC
# 4049/4131 - 4600 W 4TH AVE, Vancouver, BC: 49.268372708414766, -123.16802979988441  | ~1.37 minutes remaining
# Wrote chunk 162 to ../data/cleaned_data/block_street_with_lat_lon.csv
# Attempting to find lat/lon for 4100 GLADSTONE ST, Vancouver, BC
# 4050/4131 - 4100 GLADSTONE ST, Vancouver, BC: 49.24836521765495, -123.06050192799655  | ~1.35 minutes remaining
# Attempting to find lat/lon for 1200 MAXINE LANE, Vancouver, BC
# 4051/4131 - 1200 MAXINE LANE, Vancouver, BC: 49.2816075960739, -123.13631991022216  | ~1.33 minutes remaining
# Attempting to find lat/lon for 2800 E GEORGIA ST, Vancouver, BC
# 4052/4131 - 2800 E GEORGIA ST, Vancouver, BC: 49.2784661, -123.0235409  | ~1.32 minutes remaining
# Attempting to find lat/lon for 700 PRINCESS AVE, Vancouver, BC
# 4053/4131 - 700 PRINCESS AVE, Vancouver, BC: 49.27824645, -123.09137615259012  | ~1.30 minutes remaining
# Attempting to find lat/lon for 2000 ALMA ST, Vancouver, BC
# 4054/4131 - 2000 ALMA ST, Vancouver, BC: 49.272695695334235, -123.1855776664509  | ~1.28 minutes remaining
# Attempting to find lat/lon for 1000 HELMCKEN ST, Vancouver, BC
# 4055/4131 - 1000 HELMCKEN ST, Vancouver, BC: 49.27812185749912, -123.12448432469849  | ~1.27 minutes remaining
# Attempting to find lat/lon for 5500 DUNBAR ST, Vancouver, BC
# 4056/4131 - 5500 DUNBAR ST, Vancouver, BC: 49.26602421497274, -123.18373133802886  | ~1.25 minutes remaining
# Attempting to find lat/lon for 4300 LOCARNO CRESCENT, Vancouver, BC
# 4057/4131 - 4300 LOCARNO CRESCENT, Vancouver, BC: 49.269084043695884, -123.20432762342077  | ~1.23 minutes remaining
# Attempting to find lat/lon for 5300 FRASER ST, Vancouver, BC
# 4058/4131 - 5300 FRASER ST, Vancouver, BC: 49.26197907672559, -123.08913300412429  | ~1.22 minutes remaining
# Attempting to find lat/lon for 900 E 62ND AVE, Vancouver, BC
# 4090/4131 - 900 E 62ND AVE, Vancouver, BC: 49.213714384469995, -123.07058696565451  | ~0.68 minutes remaining
# Attempting to find lat/lon for 2700 TRINITY ST, Vancouver, BC
# 4091/4131 - 2700 TRINITY ST, Vancouver, BC: 49.28932494570334, -123.05790398111628  | ~0.67 minutes remaining
# Attempting to find lat/lon for 4100 BRANT ST, Vancouver, BC
# 4092/4131 - 4100 BRANT ST, Vancouver, BC: 49.248363820575, -123.05800820331717  | ~0.65 minutes remaining
# Attempting to find lat/lon for 3400 TURNER ST, Vancouver, BC
# 4093/4131 - 3400 TURNER ST, Vancouver, BC: 49.27908428414427, -123.0427755010141  | ~0.63 minutes remaining
# Attempting to find lat/lon for 2400 TRIUMPH ST, Vancouver, BC
# 4094/4131 - 2400 TRIUMPH ST, Vancouver, BC: 49.283922356599106, -123.06263477989124  | ~0.62 minutes remaining
# Attempting to find lat/lon for 5300 TAUNTON ST, Vancouver, BC
# 4095/4131 - 5300 TAUNTON ST, Vancouver, BC: 49.23633394011669, -123.03885119140303  | ~0.60 minutes remaining
# Attempting to find lat/lon for 700 W 15TH AVE, Vancouver, BC
# 4096/4131 - 700 W 15TH AVE, Vancouver, BC: 49.257730642146186, -123.11010823265529  | ~0.58 minutes remaining
# Attempting to find lat/lon for 3400 PRINCE ALBERT ST, Vancouver, BC
# 4097/4131 - 3400 PRINCE ALBERT ST, Vancouver, BC: 49.212924011360265, -123.08815105623131  | ~0.57 minutes remaining
# Attempting to find lat/lon for 900 E 19TH AVE, Vancouver, BC
# 4098/4131 - 900 E 19TH AVE, Vancouver, BC: 49.253399, -123.08542017536124  | ~0.55 minutes remaining
# Attempting to find lat/lon for 2200 TRIUMPH ST, Vancouver, BC
# 4099/4131 - 2200 TRIUMPH ST, Vancouver, BC: 49.283922356599106, -123.06263477989124  | ~0.53 minutes remaining
# Wrote chunk 164 to ../data/cleaned_data/block_street_with_lat_lon.csv
# Attempting to find lat/lon for 200 BOUNDARY RD, Vancouver, BC
# 4100/4131 - 200 BOUNDARY RD, Vancouver, BC: 49.20664864201525, -123.02334473319803  | ~0.52 minutes remaining
# Attempting to find lat/lon for 100 E 49TH AVE, Vancouver, BC
# 4101/4131 - 100 E 49TH AVE, Vancouver, BC: 49.224908299999996, -123.10865339884751  | ~0.50 minutes remaining
# Attempting to find lat/lon for 8400 ASH ST, Vancouver, BC
# 4102/4131 - 8400 ASH ST, Vancouver, BC: 49.234556833243914, -123.11784027039413  | ~0.48 minutes remaining
# Attempting to find lat/lon for 3200 W 27TH AVE, Vancouver, BC
# 4103/4131 - 3200 W 27TH AVE, Vancouver, BC: 49.24716431798934, -123.12360598755744  | ~0.47 minutes remaining
# Attempting to find lat/lon for 3500 MONMOUTH AVE, Vancouver, BC
# 4104/4131 - 3500 MONMOUTH AVE, Vancouver, BC: 49.239836732439336, -123.02672757850918  | ~0.45 minutes remaining
# Attempting to find lat/lon for 2600 E 52ND AVE, Vancouver, BC
# 4121/4131 - 3000 E 20TH AVE, Vancouver, BC: 49.2525707807991, -123.07417675463365  | ~0.17 minutes remaining
# Attempting to find lat/lon for 200 W 46TH AVE, Vancouver, BC
# 4122/4131 - 200 W 46TH AVE, Vancouver, BC: 49.229625570310134, -123.13738316312893  | ~0.15 minutes remaining
# Attempting to find lat/lon for 800 E 10TH AVE, Vancouver, BC
# 4123/4131 - 800 E 10TH AVE, Vancouver, BC: 49.26158087156491, -123.09514400292088  | ~0.13 minutes remaining
# Attempting to find lat/lon for 1100 MAIN ST, Vancouver, BC
# 4124/4131 - 1100 MAIN ST, Vancouver, BC: 49.264741967509515, -123.1009572308099  | ~0.12 minutes remaining
# Wrote chunk 165 to ../data/cleaned_data/block_street_with_lat_lon.csv
# Attempting to find lat/lon for 5200 DUNDEE ST, Vancouver, BC
# 4125/4131 - 5200 DUNDEE ST, Vancouver, BC: 49.235550724744144, -123.0476018940303  | ~0.10 minutes remaining
# Attempting to find lat/lon for 2700 W KING EDWARD AVE, Vancouver, BC
# 4126/4131 - 2700 W KING EDWARD AVE, Vancouver, BC: 49.24989990181952, -123.17188339933575  | ~0.08 minutes remaining
# Attempting to find lat/lon for 0 E 49TH AVE, Vancouver, BC
# 4127/4131 - 0 E 49TH AVE, Vancouver, BC: 49.2250469273952, -123.05927604991112  | ~0.07 minutes remaining
# Attempting to find lat/lon for 5300 OBEN ST, Vancouver, BC
# 4128/4131 - 5300 OBEN ST, Vancouver, BC: 49.235383260694135, -123.0264893229344  | ~0.05 minutes remaining
# Attempting to find lat/lon for 2300 W 49TH AVE, Vancouver, BC
# 4129/4131 - 2300 W 49TH AVE, Vancouver, BC: 49.22713793248659, -123.15341155736996  | ~0.03 minutes remaining
# Attempting to find lat/lon for 1500 MAXINE LANE, Vancouver, BC
# 4130/4131 - 1500 MAXINE LANE, Vancouver, BC: 49.2816075960739, -123.13631991022216  | ~0.02 minutes remaining
# Wrote chunk 165 to ../data/cleaned_data/block_street_with_lat_lon.csv

# %%
ndf = pd.read_csv("../data/cleaned_data/block_street_with_lat_lon.csv")
print(ndf.shape[0])

ndf = ndf.drop_duplicates()
print(ndf.shape[0])

print(df.shape[0])

merged = pd.merge(df, ndf, on=["Block", "Street"], how="outer")

print(f"Number of rows with NAN: {merged.isna().any(axis=1).sum()}")

merged
# Out:
# 4131
# 4130
# 4131
# Number of rows with NAN: 1
#       Block        Street        lat         lon
# 0         0     ABBOTT ST  49.284110 -123.106311
# 1         0  ALEXANDER ST  49.284079 -123.098285
# 2         0  ATHLETES WAY  49.271554 -123.106961
# 3         0    CASSIAR ST  49.248844 -123.031089
# 4         0      CHESS ST  49.273341 -123.086421
# ...     ...           ...        ...         ...
# 4126   9300        OAK ST  49.264950 -123.126546
# 4127  11100     BONSAI ST  49.257334 -123.167749
# 4128  11100  SCALES PLACE  49.240580 -123.025076
# 4129  26000     NOOTKA ST  49.249873 -123.041618
# 4130  99900     BONSAI ST        NaN         NaN
#
# [4131 rows x 4 columns]

# %%
print("Finished!")
if os.path.exists(progress_file):
    os.remove(progress_file)
# Out:
# Finished!
